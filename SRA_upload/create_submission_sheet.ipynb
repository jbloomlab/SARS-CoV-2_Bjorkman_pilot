# %% [markdown]
# # Create SRA submission sheet
# This Python Jupyter notebook creates a BioSample submission sheet for the Sequence Read Archive:
#
# First, import Python modules:

# %%
import datetime
import glob
import itertools
import os

import natsort

import pandas as pd

import yaml

# %% [markdown]
# Display full columns of data frames:

# %%
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# Read the configuration for the uploads:

# %%
with open('upload_config.yaml') as f:
    config = yaml.safe_load(f)

# %% [markdown]
# Read the Illumina runs to submit:

# %%
print(f"Reading Illumina runs from {config['barcode_runs']}")

illumina_runs = pd.read_csv(config['barcode_runs'])

print('Here are the first few entries in the Illumina runs:')
illumina_runs.head()
# Out:
# Reading Illumina runs from barcode_runs.csv
# Here are the first few entries in the Illumina runs:
#      date  experiment library     antibody  concentration sort_bin  selection  \
# 0  220118  beta_19-26    lib1         none              0      ref  reference
# 1  220118  beta_19-26    lib2         none              0      ref  reference
# 2  220118     beta_19    lib1  mosaic_6848           3125    abneg     escape
# 3  220118     beta_19    lib2  mosaic_6848           3125    abneg     escape
# 4  220118     beta_20    lib1  mosaic_6849           3125    abneg     escape
#
#                            sample experiment_type  number_cells  frac_escape  \
# 0           beta_19-26-none-0-ref    ab_selection           NaN          NaN
# 1           beta_19-26-none-0-ref    ab_selection           NaN          NaN
# 2  beta_19-mosaic_6848-3125-abneg    ab_selection      875492.0        0.096
# 3  beta_19-mosaic_6848-3125-abneg    ab_selection     1002826.0        0.136
# 4  beta_20-mosaic_6849-3125-abneg    ab_selection      957229.0        0.105
#
#                                                                                                                         R1
# 0  /shared/ngs/illumina/agreaney/220124_D00300_1402_BHNKFCBCX3/Unaligned/Project_agreaney/beta_19-26_lib1_ref*R1*.fastq.gz
# 1  /shared/ngs/illumina/agreaney/220124_D00300_1402_BHNKFCBCX3/Unaligned/Project_agreaney/beta_19-26_lib2_ref*R1*.fastq.gz
# 2   /shared/ngs/illumina/agreaney/220124_D00300_1402_BHNKFCBCX3/Unaligned/Project_agreaney/beta_19_lib1_abneg*R1*.fastq.gz
# 3   /shared/ngs/illumina/agreaney/220124_D00300_1402_BHNKFCBCX3/Unaligned/Project_agreaney/beta_19_lib2_abneg*R1*.fastq.gz
# 4   /shared/ngs/illumina/agreaney/220124_D00300_1402_BHNKFCBCX3/Unaligned/Project_agreaney/beta_20_lib1_abneg*R1*.fastq.gz

# %% [markdown]
# Next make submission entries for the barcode runs, initially in "tidy" format with one FASTQ file per row:

# %%
submissions_tidy = (
    illumina_runs
    .assign(
        biosample_accession=lambda x: config['biosample_accession'],
        library_ID=lambda x: x['library'] + '_' + x['sample'],
        title=lambda x: 'SARS-CoV-2 RBD mutational antig Illumina barcode sequencing for ' + x['sample'],
        library_strategy='AMPLICON',
        library_source='SYNTHETIC',
        library_selection='PCR',
        library_layout='single',
        platform='ILLUMINA',
        instrument_model='Illumina HiSeq 2500',
        design_description='PCR of barcodes from RBD variants',
        filetype='fastq',
        filename_fullpath=lambda x: x['R1'].str.split(';')
                                    .map(lambda flist: list(itertools.chain.from_iterable(glob.glob(f) for f in flist))),       
        )
    .explode('filename_fullpath')
    .assign(filename_fullpath=lambda x: x['filename_fullpath'].str.strip(),
            filename=lambda x: x['filename_fullpath'].map(os.path.basename))
    .drop(columns=illumina_runs.columns)
    .reset_index(drop=True)
    )

assert submissions_tidy['filename_fullpath'].map(os.path.isfile).all()

print('Here are the first few submission entries in tidy format:')
submissions_tidy.head()
# Out:
# Here are the first few submission entries in tidy format:
#   biosample_accession                  library_ID  \
# 0        SAMN26315988  lib1_beta_19-26-none-0-ref
# 1        SAMN26315988  lib1_beta_19-26-none-0-ref
# 2        SAMN26315988  lib1_beta_19-26-none-0-ref
# 3        SAMN26315988  lib1_beta_19-26-none-0-ref
# 4        SAMN26315988  lib2_beta_19-26-none-0-ref
#
#                                                                                    title  \
# 0  SARS-CoV-2 RBD mutational antig Illumina barcode sequencing for beta_19-26-none-0-ref
# 1  SARS-CoV-2 RBD mutational antig Illumina barcode sequencing for beta_19-26-none-0-ref
# 2  SARS-CoV-2 RBD mutational antig Illumina barcode sequencing for beta_19-26-none-0-ref
# 3  SARS-CoV-2 RBD mutational antig Illumina barcode sequencing for beta_19-26-none-0-ref
# 4  SARS-CoV-2 RBD mutational antig Illumina barcode sequencing for beta_19-26-none-0-ref
#
#   library_strategy library_source library_selection library_layout  platform  \
# 0         AMPLICON      SYNTHETIC               PCR         single  ILLUMINA
# 1         AMPLICON      SYNTHETIC               PCR         single  ILLUMINA
# 2         AMPLICON      SYNTHETIC               PCR         single  ILLUMINA
# 3         AMPLICON      SYNTHETIC               PCR         single  ILLUMINA
# 4         AMPLICON      SYNTHETIC               PCR         single  ILLUMINA
#
#       instrument_model                 design_description filetype  \
# 0  Illumina HiSeq 2500  PCR of barcodes from RBD variants    fastq
# 1  Illumina HiSeq 2500  PCR of barcodes from RBD variants    fastq
# 2  Illumina HiSeq 2500  PCR of barcodes from RBD variants    fastq
# 3  Illumina HiSeq 2500  PCR of barcodes from RBD variants    fastq
# 4  Illumina HiSeq 2500  PCR of barcodes from RBD variants    fastq
#
#                                                                                                                  filename_fullpath  \
# 0  /shared/ngs/illumina/agreaney/220124_D00300_1402_BHNKFCBCX3/Unaligned/Project_agreaney/beta_19-26_lib1_ref-3_S3_R1_001.fastq.gz
# 1  /shared/ngs/illumina/agreaney/220124_D00300_1402_BHNKFCBCX3/Unaligned/Project_agreaney/beta_19-26_lib1_ref-2_S2_R1_001.fastq.gz
# 2  /shared/ngs/illumina/agreaney/220124_D00300_1402_BHNKFCBCX3/Unaligned/Project_agreaney/beta_19-26_lib1_ref-4_S4_R1_001.fastq.gz
# 3  /shared/ngs/illumina/agreaney/220124_D00300_1402_BHNKFCBCX3/Unaligned/Project_agreaney/beta_19-26_lib1_ref-1_S1_R1_001.fastq.gz
# 4  /shared/ngs/illumina/agreaney/220124_D00300_1402_BHNKFCBCX3/Unaligned/Project_agreaney/beta_19-26_lib2_ref-2_S6_R1_001.fastq.gz
#
#                                    filename
# 0  beta_19-26_lib1_ref-3_S3_R1_001.fastq.gz
# 1  beta_19-26_lib1_ref-2_S2_R1_001.fastq.gz
# 2  beta_19-26_lib1_ref-4_S4_R1_001.fastq.gz
# 3  beta_19-26_lib1_ref-1_S1_R1_001.fastq.gz
# 4  beta_19-26_lib2_ref-2_S6_R1_001.fastq.gz

# %% [markdown]
# For the actual submission, we need a "wide" data frame that for each unique `sample_name` / `library_ID` gives all of the files each in different columns.
# These should be files without the full path.
#
# First, look at how many files there are for each sample / library:

# %%
(submissions_tidy
 .groupby(['biosample_accession', 'library_ID'])
 .aggregate(n_files=pd.NamedAgg('filename_fullpath', 'count'))
 .sort_values('n_files', ascending=False)
 .reset_index()
 )
# Out:
#    biosample_accession                                library_ID  n_files
# 0         SAMN26315988                lib1_beta_19-26-none-0-ref        4
# 1         SAMN26315988                lib1_beta_27-34-none-0-ref        4
# 2         SAMN26315988                lib2_beta_27-34-none-0-ref        4
# 3         SAMN26315988                lib2_beta_19-26-none-0-ref        4
# 4         SAMN26315988       lib1_beta_22-mosaic_6851-3125-abneg        1
# 5         SAMN26315988       lib1_beta_23-mosaic_6852-3125-abneg        1
# 6         SAMN26315988    lib2_beta_33-NHP_mosaic_0Z5-1000-abneg        1
# 7         SAMN26315988    lib2_beta_32-NHP_mosaic_AO2-1000-abneg        1
# 8         SAMN26315988  lib2_beta_31-NHP_mosaic_MA292-1000-abneg        1
# 9         SAMN26315988    lib2_beta_30-homotypic_6885-5000-abneg        1
# 10        SAMN26315988    lib2_beta_29-homotypic_6884-5000-abneg        1
# 11        SAMN26315988    lib2_beta_28-homotypic_6882-5000-abneg        1
# 12        SAMN26315988    lib2_beta_27-homotypic_6880-5000-abneg        1
# 13        SAMN26315988       lib1_beta_20-mosaic_6849-3125-abneg        1
# 14        SAMN26315988    lib2_beta_26-homotypic_6883-7812-abneg        1
# 15        SAMN26315988    lib2_beta_25-homotypic_6881-7812-abneg        1
# 16        SAMN26315988       lib2_beta_24-mosaic_6853-3125-abneg        1
# 17        SAMN26315988       lib2_beta_23-mosaic_6852-3125-abneg        1
# 18        SAMN26315988       lib2_beta_22-mosaic_6851-3125-abneg        1
# 19        SAMN26315988       lib2_beta_21-mosaic_6850-3125-abneg        1
# 20        SAMN26315988       lib2_beta_20-mosaic_6849-3125-abneg        1
# 21        SAMN26315988       lib2_beta_19-mosaic_6848-3125-abneg        1
# 22        SAMN26315988       lib1_beta_19-mosaic_6848-3125-abneg        1
# 23        SAMN26315988    lib1_beta_34-NHP_mosaic_AT5-1000-abneg        1
# 24        SAMN26315988    lib1_beta_33-NHP_mosaic_0Z5-1000-abneg        1
# 25        SAMN26315988    lib1_beta_32-NHP_mosaic_AO2-1000-abneg        1
# 26        SAMN26315988  lib1_beta_31-NHP_mosaic_MA292-1000-abneg        1
# 27        SAMN26315988    lib1_beta_30-homotypic_6885-5000-abneg        1
# 28        SAMN26315988    lib1_beta_29-homotypic_6884-5000-abneg        1
# 29        SAMN26315988    lib1_beta_28-homotypic_6882-5000-abneg        1
# 30        SAMN26315988    lib1_beta_27-homotypic_6880-5000-abneg        1
# 31        SAMN26315988       lib1_beta_21-mosaic_6850-3125-abneg        1
# 32        SAMN26315988    lib1_beta_26-homotypic_6883-7812-abneg        1
# 33        SAMN26315988    lib1_beta_25-homotypic_6881-7812-abneg        1
# 34        SAMN26315988       lib1_beta_24-mosaic_6853-3125-abneg        1
# 35        SAMN26315988    lib2_beta_34-NHP_mosaic_AT5-1000-abneg        1

# %% [markdown]
# Now make the wide submission data frame.
# Note we keep only the filename column with the path lacking the full directory information:

# %%
submissions_wide = (
    submissions_tidy
    .assign(
        filename_count=lambda x: x.groupby(['biosample_accession', 'library_ID'])['filename'].cumcount() + 1,
        filename_col=lambda x: 'filename' + x['filename_count'].map(lambda c: str(c) if c > 1 else '')
        )
    .pivot(
        index='library_ID',
        columns='filename_col',
        values='filename',
        )
    )

submissions_wide = (
    submissions_tidy
    .drop(columns=['filename_fullpath', 'filename'])
    .drop_duplicates()
    .merge(submissions_wide[natsort.natsorted(submissions_wide.columns)],
           on='library_ID',
           validate='one_to_one',
           )
    )

print('Here are the first few submission entries in wide format:')
submissions_wide.head()
# Out:
# Here are the first few submission entries in wide format:
#   biosample_accession                           library_ID  \
# 0        SAMN26315988           lib1_beta_19-26-none-0-ref
# 1        SAMN26315988           lib2_beta_19-26-none-0-ref
# 2        SAMN26315988  lib1_beta_19-mosaic_6848-3125-abneg
# 3        SAMN26315988  lib2_beta_19-mosaic_6848-3125-abneg
# 4        SAMN26315988  lib1_beta_20-mosaic_6849-3125-abneg
#
#                                                                                             title  \
# 0           SARS-CoV-2 RBD mutational antig Illumina barcode sequencing for beta_19-26-none-0-ref
# 1           SARS-CoV-2 RBD mutational antig Illumina barcode sequencing for beta_19-26-none-0-ref
# 2  SARS-CoV-2 RBD mutational antig Illumina barcode sequencing for beta_19-mosaic_6848-3125-abneg
# 3  SARS-CoV-2 RBD mutational antig Illumina barcode sequencing for beta_19-mosaic_6848-3125-abneg
# 4  SARS-CoV-2 RBD mutational antig Illumina barcode sequencing for beta_20-mosaic_6849-3125-abneg
#
#   library_strategy library_source library_selection library_layout  platform  \
# 0         AMPLICON      SYNTHETIC               PCR         single  ILLUMINA
# 1         AMPLICON      SYNTHETIC               PCR         single  ILLUMINA
# 2         AMPLICON      SYNTHETIC               PCR         single  ILLUMINA
# 3         AMPLICON      SYNTHETIC               PCR         single  ILLUMINA
# 4         AMPLICON      SYNTHETIC               PCR         single  ILLUMINA
#
#       instrument_model                 design_description filetype  \
# 0  Illumina HiSeq 2500  PCR of barcodes from RBD variants    fastq
# 1  Illumina HiSeq 2500  PCR of barcodes from RBD variants    fastq
# 2  Illumina HiSeq 2500  PCR of barcodes from RBD variants    fastq
# 3  Illumina HiSeq 2500  PCR of barcodes from RBD variants    fastq
# 4  Illumina HiSeq 2500  PCR of barcodes from RBD variants    fastq
#
#                                    filename  \
# 0  beta_19-26_lib1_ref-3_S3_R1_001.fastq.gz
# 1  beta_19-26_lib2_ref-2_S6_R1_001.fastq.gz
# 2     beta_19_lib1_abneg_S9_R1_001.fastq.gz
# 3    beta_19_lib2_abneg_S17_R1_001.fastq.gz
# 4    beta_20_lib1_abneg_S10_R1_001.fastq.gz
#
#                                   filename2  \
# 0  beta_19-26_lib1_ref-2_S2_R1_001.fastq.gz
# 1  beta_19-26_lib2_ref-4_S8_R1_001.fastq.gz
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#                                   filename3  \
# 0  beta_19-26_lib1_ref-4_S4_R1_001.fastq.gz
# 1  beta_19-26_lib2_ref-1_S5_R1_001.fastq.gz
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#                                   filename4
# 0  beta_19-26_lib1_ref-1_S1_R1_001.fastq.gz
# 1  beta_19-26_lib2_ref-3_S7_R1_001.fastq.gz
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN

# %% [markdown]
# Now write the wide submissions data frame to a `*.tsv` file that can be used for uploading the SRA submission website:

# %%
submissions_spreadsheet = 'SRA_submission_spreadsheet.tsv'

submissions_wide.to_csv(submissions_spreadsheet, sep='\t', index=False)

# %% [markdown]
# We also want to write a file with all of the FASTQ files that are in the submission spreadsheet:

# %%
fastq_file_list = 'FASTQs_to_upload.csv'

print(f"Writing list of all the FASTQ files to upload to {fastq_file_list}")

(submissions_tidy
 [['filename_fullpath', 'filename']]
 .to_csv(fastq_file_list, index=False)
 )
# Out:
# Writing list of all the FASTQ files to upload to FASTQs_to_upload.csv
